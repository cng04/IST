# %%
import pandas as pd

# %%
player_box_score_stats = pd.read_excel("data/usports_stats_data.xlsx")
player_box_score_stats
# Out:
#                   Player   Season  GP-GS  Mins   MPG  3 Pt_1  3 Pt_2  \
# 0     Khalid Abdel-Gabar  2013-14  27-11   607  22.5   27-75    36.0
# 1     Khalid Abdel-Gabar  2014-15  30-30   905  30.2  53-163    32.5
# 2     Khalid Abdel-Gabar    Total  57-41  1512  26.5  80-238    33.6
# 3            Jamil Abiad  2009-10   23-0   254  11.0   21-61    34.4
# 4            Jamil Abiad  2012-13   12-0   139  11.6    4-18    22.2
# ...                  ...      ...    ...   ...   ...     ...     ...
# 3667       Kristian Zjak  2018-19   16-0   141   8.8     0-0     0.0
# 3668       Kristian Zjak    Total   37-8   465  12.6     0-0     0.0
# 3669            Jim Zoet  1976-77     33     0   0.0     NaN     NaN
# 3670            Jim Zoet  1977-78     34     0   0.0     NaN     NaN
# 3671            Jim Zoet    Total     67     0   0.0     NaN     NaN
#
#      Field Goals_1  Field Goals_2 Free Throws_1  Free Throws_2  Rebounds_1  \
# 0           91-205           44.4         20-32           62.5         107
# 1          146-368           39.7         43-67           64.2         115
# 2          237-573           41.4         63-99           63.6         222
# 3            32-86           37.2          6-10           60.0          32
# 4            11-33           33.3           3-5           60.0          15
# ...            ...            ...           ...            ...         ...
# 3667         24-43           55.8         11-22           50.0          40
# 3668         54-98           55.1         17-40           42.5         133
# 3669       230-472           48.7        85-109           78.0         465
# 3670       314-568           55.3       100-154           64.9         494
# 3671      544-1040           52.3       185-263           70.3         959
#
#       Rebounds_2     PF     AS     TO    BL    ST  Points_1  Points_2
# 0            4.0   49.0   54.0   36.0   6.0  50.0       229       8.5
# 1            3.8   47.0  100.0   60.0   3.0  41.0       388      12.9
# 2            3.9   96.0  154.0   96.0   9.0  91.0       617      10.8
# 3            1.4   32.0   14.0   31.0   NaN  13.0        91       4.0
# 4            1.2   16.0    7.0    4.0   NaN   5.0        29       2.4
# ...          ...    ...    ...    ...   ...   ...       ...       ...
# 3667         2.5   16.0    5.0   10.0   4.0   NaN        59       3.7
# 3668         3.6   59.0   15.0   38.0  17.0   4.0       125       3.4
# 3669        14.1  109.0    NaN   61.0   NaN   NaN       545      16.5
# 3670        14.5  105.0    NaN   95.0   NaN   NaN       728      21.4
# 3671        14.3  214.0    NaN  156.0   NaN   NaN      1273      19.0
#
# [3672 rows x 20 columns]

# %%
manually_scraped_player = pd.read_excel("data/players_missing_usports_stats.xlsx")
manually_scraped_player
# Out:
#                           Player
# 0               Sami Al Uariachi
# 1                   John Bantock
# 2                     Cliff Bell
# 3                Brandon Bilbija
# 4                Arnar Bjornsson
# 5                 Nicolas Blanas
# 6                 Jason J. Brade
# 7                    Thomas Cory
# 8                 Whitney Dabney
# 9         Claude Delmas-Merisier
# 10             Lawrence Dudevoir
# 11                 Simon Dykstra
# 12              Adil El Makssoud
# 13                 David Elliott
# 14         Kevin Leander Fiabema
# 15                 Kirk Francois
# 16                 Jerome Gaines
# 17       Atanas (Nasko) Golomeev
# 18     Daniel Gonzalez Longarela
# 19            Marc Antoine Horth
# 20              Terence Hyacinth
# 21                  Steve Irvine
# 22    Misi Boye Jeanneau-Mubiala
# 23                 Omar Jennings
# 24                 Djordje Jovic
# 25                     Sean Kask
# 26             Michael Kelvin II
# 27                   Real Kitieu
# 28                   Radhi Knapp
# 29       Franck Olivier Kouagnia
# 30            Sebastien Lapointe
# 31          Islam Luiz de Toledo
# 32                Bernhard Maerz
# 33                   Ali Mahmoud
# 34                    Paul Nixon
# 35              David John Oates
# 36           Rotimi Osuntola Jr.
# 37  Jean Emmanuel Pierre-Charles
# 38    Alejandro Prescott-Cornejo
# 39                  Euan Roberts
# 40            N'Kosi Kedar Salam
# 41                   Ethan Scott
# 42       Ismar Serferagic Kriese
# 43                 Rob Smart Jr.
# 44               Kevin St. Kitts
# 45                 Novell Thomas
# 46             Earl Thompson Jr.
# 47                   Burke Toews
# 48                   Konrad Tota
# 49                Henry Van Herk
# 50              Bas van Willigen
# 51             Samuel Willis III
# 52                   Gilles Ysos
# 53              Luka Zaharijevic

# %%
df = pd.concat([player_box_score_stats, manually_scraped_player], ignore_index=True)
df
# Out:
#                   Player   Season  GP-GS    Mins   MPG  3 Pt_1  3 Pt_2  \
# 0     Khalid Abdel-Gabar  2013-14  27-11   607.0  22.5   27-75    36.0
# 1     Khalid Abdel-Gabar  2014-15  30-30   905.0  30.2  53-163    32.5
# 2     Khalid Abdel-Gabar    Total  57-41  1512.0  26.5  80-238    33.6
# 3            Jamil Abiad  2009-10   23-0   254.0  11.0   21-61    34.4
# 4            Jamil Abiad  2012-13   12-0   139.0  11.6    4-18    22.2
# ...                  ...      ...    ...     ...   ...     ...     ...
# 3721      Henry Van Herk      NaN    NaN     NaN   NaN     NaN     NaN
# 3722    Bas van Willigen      NaN    NaN     NaN   NaN     NaN     NaN
# 3723   Samuel Willis III      NaN    NaN     NaN   NaN     NaN     NaN
# 3724         Gilles Ysos      NaN    NaN     NaN   NaN     NaN     NaN
# 3725    Luka Zaharijevic      NaN    NaN     NaN   NaN     NaN     NaN
#
#      Field Goals_1  Field Goals_2 Free Throws_1  Free Throws_2  Rebounds_1  \
# 0           91-205           44.4         20-32           62.5       107.0
# 1          146-368           39.7         43-67           64.2       115.0
# 2          237-573           41.4         63-99           63.6       222.0
# 3            32-86           37.2          6-10           60.0        32.0
# 4            11-33           33.3           3-5           60.0        15.0
# ...            ...            ...           ...            ...         ...
# 3721           NaN            NaN           NaN            NaN         NaN
# 3722           NaN            NaN           NaN            NaN         NaN
# 3723           NaN            NaN           NaN            NaN         NaN
# 3724           NaN            NaN           NaN            NaN         NaN
# 3725           NaN            NaN           NaN            NaN         NaN
#
#       Rebounds_2    PF     AS    TO   BL    ST  Points_1  Points_2
# 0            4.0  49.0   54.0  36.0  6.0  50.0     229.0       8.5
# 1            3.8  47.0  100.0  60.0  3.0  41.0     388.0      12.9
# 2            3.9  96.0  154.0  96.0  9.0  91.0     617.0      10.8
# 3            1.4  32.0   14.0  31.0  NaN  13.0      91.0       4.0
# 4            1.2  16.0    7.0   4.0  NaN   5.0      29.0       2.4
# ...          ...   ...    ...   ...  ...   ...       ...       ...
# 3721         NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3722         NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3723         NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3724         NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3725         NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
#
# [3726 rows x 20 columns]

# %%
usports_to_pro_summary = pd.read_excel("data/usports_players_to_pro_summary.xlsx")

# Merge with usports_to_pro_summary
df = df.merge(
    usports_to_pro_summary[["Player", "Position", "Hometown", "U Sports Team"]],
    on="Player",
    how="left"
)

cols = (
    ["Player", "Position", "Hometown", "U Sports Team"]
    + [c for c in df.columns if c not in ["Player", "Position", "Hometown", "U Sports Team"]]
)

df = df[cols]
df
# Out:
#                   Player     Position         Hometown U Sports Team   Season  \
# 0     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor  2013-14
# 1     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor  2014-15
# 2     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor    Total
# 3            Jamil Abiad   Guard 5-11       Ottawa, ON      Bishop's  2009-10
# 4            Jamil Abiad   Guard 5-11       Ottawa, ON      Bishop's  2012-13
# ...                  ...          ...              ...           ...      ...
# 3721      Henry Van Herk  Forward 6-9      Toronto, ON       Queen's      NaN
# 3722    Bas van Willigen  Forward 6-7      Netherlands          UCCB      NaN
# 3723   Samuel Willis III    Guard 6-1  Minneapolis, MN   Mount Royal      NaN
# 3724         Gilles Ysos    Guard 6-1     Agen, France          UQAM      NaN
# 3725    Luka Zaharijevic  Forward 6-8    Vancouver, BC           UBC      NaN
#
#       GP-GS    Mins   MPG  3 Pt_1  3 Pt_2  ... Free Throws_2  Rebounds_1  \
# 0     27-11   607.0  22.5   27-75    36.0  ...          62.5       107.0
# 1     30-30   905.0  30.2  53-163    32.5  ...          64.2       115.0
# 2     57-41  1512.0  26.5  80-238    33.6  ...          63.6       222.0
# 3      23-0   254.0  11.0   21-61    34.4  ...          60.0        32.0
# 4      12-0   139.0  11.6    4-18    22.2  ...          60.0        15.0
# ...     ...     ...   ...     ...     ...  ...           ...         ...
# 3721    NaN     NaN   NaN     NaN     NaN  ...           NaN         NaN
# 3722    NaN     NaN   NaN     NaN     NaN  ...           NaN         NaN
# 3723    NaN     NaN   NaN     NaN     NaN  ...           NaN         NaN
# 3724    NaN     NaN   NaN     NaN     NaN  ...           NaN         NaN
# 3725    NaN     NaN   NaN     NaN     NaN  ...           NaN         NaN
#
#      Rebounds_2    PF     AS    TO   BL    ST  Points_1  Points_2
# 0           4.0  49.0   54.0  36.0  6.0  50.0     229.0       8.5
# 1           3.8  47.0  100.0  60.0  3.0  41.0     388.0      12.9
# 2           3.9  96.0  154.0  96.0  9.0  91.0     617.0      10.8
# 3           1.4  32.0   14.0  31.0  NaN  13.0      91.0       4.0
# 4           1.2  16.0    7.0   4.0  NaN   5.0      29.0       2.4
# ...         ...   ...    ...   ...  ...   ...       ...       ...
# 3721        NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3722        NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3723        NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3724        NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
# 3725        NaN   NaN    NaN   NaN  NaN   NaN       NaN       NaN
#
# [3726 rows x 23 columns]

# %%
df[df["Player"] == "Achuil Lual"]
# Out:
#            Player     Position    Hometown U Sports Team   Season   GP-GS  \
# 1904  Achuil Lual  Forward 6-9  Ottawa, ON        Acadia  2004-05   35-33
# 1905  Achuil Lual  Forward 6-9  Ottawa, ON        Acadia  2006-07   38-33
# 1906  Achuil Lual  Forward 6-9  Ottawa, ON        Acadia  2007-08   34-18
# 1907  Achuil Lual  Forward 6-9  Ottawa, ON        Acadia    Total  107-84
#
#         Mins   MPG 3 Pt_1  3 Pt_2  ... Free Throws_2  Rebounds_1 Rebounds_2  \
# 1904   824.0  23.5    1-6    16.7  ...          52.4       251.0        7.2
# 1905  1085.0  28.6    0-0     0.0  ...          57.0       298.0        7.8
# 1906   757.0  22.3    0-1     0.0  ...          52.1       199.0        5.9
# 1907  2666.0  24.9    1-7    14.3  ...          54.2       748.0        7.0
#
#          PF     AS     TO     BL    ST  Points_1  Points_2
# 1904  111.0   30.0   56.0   33.0  27.0     276.0       7.9
# 1905  111.0   74.0   60.0   60.0  28.0     347.0       9.1
# 1906  102.0   64.0   67.0   40.0  15.0     224.0       6.6
# 1907  324.0  168.0  183.0  133.0  70.0     847.0       7.9
#
# [4 rows x 23 columns]

# %%
# Drop Unnecessary Columns
df = df.drop(columns=["Mins", "Rebounds_1", "Points_1"])
df
# Out:
#                   Player     Position         Hometown U Sports Team   Season  \
# 0     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor  2013-14
# 1     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor  2014-15
# 2     Khalid Abdel-Gabar    Guard 6-2  Mississauga, ON       Windsor    Total
# 3            Jamil Abiad   Guard 5-11       Ottawa, ON      Bishop's  2009-10
# 4            Jamil Abiad   Guard 5-11       Ottawa, ON      Bishop's  2012-13
# ...                  ...          ...              ...           ...      ...
# 3721      Henry Van Herk  Forward 6-9      Toronto, ON       Queen's      NaN
# 3722    Bas van Willigen  Forward 6-7      Netherlands          UCCB      NaN
# 3723   Samuel Willis III    Guard 6-1  Minneapolis, MN   Mount Royal      NaN
# 3724         Gilles Ysos    Guard 6-1     Agen, France          UQAM      NaN
# 3725    Luka Zaharijevic  Forward 6-8    Vancouver, BC           UBC      NaN
#
#       GP-GS   MPG  3 Pt_1  3 Pt_2 Field Goals_1  Field Goals_2 Free Throws_1  \
# 0     27-11  22.5   27-75    36.0        91-205           44.4         20-32
# 1     30-30  30.2  53-163    32.5       146-368           39.7         43-67
# 2     57-41  26.5  80-238    33.6       237-573           41.4         63-99
# 3      23-0  11.0   21-61    34.4         32-86           37.2          6-10
# 4      12-0  11.6    4-18    22.2         11-33           33.3           3-5
# ...     ...   ...     ...     ...           ...            ...           ...
# 3721    NaN   NaN     NaN     NaN           NaN            NaN           NaN
# 3722    NaN   NaN     NaN     NaN           NaN            NaN           NaN
# 3723    NaN   NaN     NaN     NaN           NaN            NaN           NaN
# 3724    NaN   NaN     NaN     NaN           NaN            NaN           NaN
# 3725    NaN   NaN     NaN     NaN           NaN            NaN           NaN
#
#       Free Throws_2  Rebounds_2    PF     AS    TO   BL    ST  Points_2
# 0              62.5         4.0  49.0   54.0  36.0  6.0  50.0       8.5
# 1              64.2         3.8  47.0  100.0  60.0  3.0  41.0      12.9
# 2              63.6         3.9  96.0  154.0  96.0  9.0  91.0      10.8
# 3              60.0         1.4  32.0   14.0  31.0  NaN  13.0       4.0
# 4              60.0         1.2  16.0    7.0   4.0  NaN   5.0       2.4
# ...             ...         ...   ...    ...   ...  ...   ...       ...
# 3721            NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3722            NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3723            NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3724            NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3725            NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
#
# [3726 rows x 20 columns]

# %%
# Split Position into Position and Height
split_cols = df["Position"].str.split(" ", n=2, expand=True)
pos_map = {"Guard": "G", "Forward": "F", "Centre": "C", "Wing": "G/F", "Guard/Wing": "G/F", "Ailier": "SF", "Arriere": "SG", "Meneur": "PG", "Centre/Forward": "C/F", "Garde": "G", "Guard-Forward": "G/F", "Guard/Forward": "G/F", "Post": "F/C", "Point Guard": "PG"}

def map_position(row):
    # try two-word combo
    if pd.notna(row[1]):
        two_word = f"{row[0]} {row[1]}"
        if two_word in pos_map:
            return pos_map[two_word], row[2]  # use 3rd column as height
    # otherwise, use single-word
    return pos_map.get(row[0], row[0]), row[1]

df[["Position", "Height"]] = split_cols.apply(map_position, axis=1, result_type="expand")
cols = list(df.columns)
pos_idx = cols.index("Position")
cols.remove("Height")
cols.insert(pos_idx + 1, "Height")

# reorder dataframe
df = df[cols]
df
# Out:
#                   Player Position Height         Hometown U Sports Team  \
# 0     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 1     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 2     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 3            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# 4            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# ...                  ...      ...    ...              ...           ...
# 3721      Henry Van Herk        F    6-9      Toronto, ON       Queen's
# 3722    Bas van Willigen        F    6-7      Netherlands          UCCB
# 3723   Samuel Willis III        G    6-1  Minneapolis, MN   Mount Royal
# 3724         Gilles Ysos        G    6-1     Agen, France          UQAM
# 3725    Luka Zaharijevic        F    6-8    Vancouver, BC           UBC
#
#        Season  GP-GS   MPG  3 Pt_1  3 Pt_2  ... Field Goals_2  Free Throws_1  \
# 0     2013-14  27-11  22.5   27-75    36.0  ...          44.4          20-32
# 1     2014-15  30-30  30.2  53-163    32.5  ...          39.7          43-67
# 2       Total  57-41  26.5  80-238    33.6  ...          41.4          63-99
# 3     2009-10   23-0  11.0   21-61    34.4  ...          37.2           6-10
# 4     2012-13   12-0  11.6    4-18    22.2  ...          33.3            3-5
# ...       ...    ...   ...     ...     ...  ...           ...            ...
# 3721      NaN    NaN   NaN     NaN     NaN  ...           NaN            NaN
# 3722      NaN    NaN   NaN     NaN     NaN  ...           NaN            NaN
# 3723      NaN    NaN   NaN     NaN     NaN  ...           NaN            NaN
# 3724      NaN    NaN   NaN     NaN     NaN  ...           NaN            NaN
# 3725      NaN    NaN   NaN     NaN     NaN  ...           NaN            NaN
#
#      Free Throws_2  Rebounds_2    PF     AS    TO   BL    ST  Points_2
# 0             62.5         4.0  49.0   54.0  36.0  6.0  50.0       8.5
# 1             64.2         3.8  47.0  100.0  60.0  3.0  41.0      12.9
# 2             63.6         3.9  96.0  154.0  96.0  9.0  91.0      10.8
# 3             60.0         1.4  32.0   14.0  31.0  NaN  13.0       4.0
# 4             60.0         1.2  16.0    7.0   4.0  NaN   5.0       2.4
# ...            ...         ...   ...    ...   ...  ...   ...       ...
# 3721           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3722           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3723           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3724           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3725           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
#
# [3726 rows x 21 columns]

# %%
# Split GP-GS column
split_cols = df["GP-GS"].str.split("-", n=1, expand=True)
gp_gs_index = df.columns.get_loc("GP-GS")
df.insert(gp_gs_index + 1, "GP", pd.to_numeric(split_cols[0], errors="coerce").astype("Int64"))
df.insert(gp_gs_index + 2, "GS", pd.to_numeric(split_cols[1], errors="coerce").astype("Int64"))
df = df.drop(columns=["GP-GS"])
df
# Out:
#                   Player Position Height         Hometown U Sports Team  \
# 0     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 1     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 2     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 3            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# 4            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# ...                  ...      ...    ...              ...           ...
# 3721      Henry Van Herk        F    6-9      Toronto, ON       Queen's
# 3722    Bas van Willigen        F    6-7      Netherlands          UCCB
# 3723   Samuel Willis III        G    6-1  Minneapolis, MN   Mount Royal
# 3724         Gilles Ysos        G    6-1     Agen, France          UQAM
# 3725    Luka Zaharijevic        F    6-8    Vancouver, BC           UBC
#
#        Season    GP    GS   MPG  3 Pt_1  ...  Field Goals_2 Free Throws_1  \
# 0     2013-14    27    11  22.5   27-75  ...           44.4         20-32
# 1     2014-15    30    30  30.2  53-163  ...           39.7         43-67
# 2       Total    57    41  26.5  80-238  ...           41.4         63-99
# 3     2009-10    23     0  11.0   21-61  ...           37.2          6-10
# 4     2012-13    12     0  11.6    4-18  ...           33.3           3-5
# ...       ...   ...   ...   ...     ...  ...            ...           ...
# 3721      NaN  <NA>  <NA>   NaN     NaN  ...            NaN           NaN
# 3722      NaN  <NA>  <NA>   NaN     NaN  ...            NaN           NaN
# 3723      NaN  <NA>  <NA>   NaN     NaN  ...            NaN           NaN
# 3724      NaN  <NA>  <NA>   NaN     NaN  ...            NaN           NaN
# 3725      NaN  <NA>  <NA>   NaN     NaN  ...            NaN           NaN
#
#       Free Throws_2 Rebounds_2    PF     AS    TO   BL    ST  Points_2
# 0              62.5        4.0  49.0   54.0  36.0  6.0  50.0       8.5
# 1              64.2        3.8  47.0  100.0  60.0  3.0  41.0      12.9
# 2              63.6        3.9  96.0  154.0  96.0  9.0  91.0      10.8
# 3              60.0        1.4  32.0   14.0  31.0  NaN  13.0       4.0
# 4              60.0        1.2  16.0    7.0   4.0  NaN   5.0       2.4
# ...             ...        ...   ...    ...   ...  ...   ...       ...
# 3721            NaN        NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3722            NaN        NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3723            NaN        NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3724            NaN        NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3725            NaN        NaN   NaN    NaN   NaN  NaN   NaN       NaN
#
# [3726 rows x 22 columns]

# %%
# Split 3PT column
split_cols = df["3 Pt_1"].str.split("-", n=1, expand=True)
index = df.columns.get_loc("3 Pt_1")
df.insert(index + 1, "3PM", pd.to_numeric(split_cols[0], errors="coerce").astype("Int64"))
df.insert(index + 2, "3PA", pd.to_numeric(split_cols[1], errors="coerce").astype("Int64"))
df = df.drop(columns=["3 Pt_1"])

# Rename 3PT% Column
df = df.rename(columns={"3 Pt_2": "3P%"})
df["3P%"] = df["3P%"].astype(float)
df
# Out:
#                   Player Position Height         Hometown U Sports Team  \
# 0     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 1     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 2     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 3            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# 4            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# ...                  ...      ...    ...              ...           ...
# 3721      Henry Van Herk        F    6-9      Toronto, ON       Queen's
# 3722    Bas van Willigen        F    6-7      Netherlands          UCCB
# 3723   Samuel Willis III        G    6-1  Minneapolis, MN   Mount Royal
# 3724         Gilles Ysos        G    6-1     Agen, France          UQAM
# 3725    Luka Zaharijevic        F    6-8    Vancouver, BC           UBC
#
#        Season    GP    GS   MPG   3PM  ...  Field Goals_2  Free Throws_1  \
# 0     2013-14    27    11  22.5    27  ...           44.4          20-32
# 1     2014-15    30    30  30.2    53  ...           39.7          43-67
# 2       Total    57    41  26.5    80  ...           41.4          63-99
# 3     2009-10    23     0  11.0    21  ...           37.2           6-10
# 4     2012-13    12     0  11.6     4  ...           33.3            3-5
# ...       ...   ...   ...   ...   ...  ...            ...            ...
# 3721      NaN  <NA>  <NA>   NaN  <NA>  ...            NaN            NaN
# 3722      NaN  <NA>  <NA>   NaN  <NA>  ...            NaN            NaN
# 3723      NaN  <NA>  <NA>   NaN  <NA>  ...            NaN            NaN
# 3724      NaN  <NA>  <NA>   NaN  <NA>  ...            NaN            NaN
# 3725      NaN  <NA>  <NA>   NaN  <NA>  ...            NaN            NaN
#
#      Free Throws_2  Rebounds_2    PF     AS    TO   BL    ST  Points_2
# 0             62.5         4.0  49.0   54.0  36.0  6.0  50.0       8.5
# 1             64.2         3.8  47.0  100.0  60.0  3.0  41.0      12.9
# 2             63.6         3.9  96.0  154.0  96.0  9.0  91.0      10.8
# 3             60.0         1.4  32.0   14.0  31.0  NaN  13.0       4.0
# 4             60.0         1.2  16.0    7.0   4.0  NaN   5.0       2.4
# ...            ...         ...   ...    ...   ...  ...   ...       ...
# 3721           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3722           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3723           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3724           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
# 3725           NaN         NaN   NaN    NaN   NaN  NaN   NaN       NaN
#
# [3726 rows x 23 columns]

# %%
# Split Field Goals column
split_cols = df["Field Goals_1"].str.split("-", n=1, expand=True)
index = df.columns.get_loc("Field Goals_1")
df.insert(index + 1, "FGM", pd.to_numeric(split_cols[0], errors="coerce").astype("Int64"))
df.insert(index + 2, "FGA", pd.to_numeric(split_cols[1], errors="coerce").astype("Int64"))
df = df.drop(columns=["Field Goals_1"])

# Rename FG% Column
df = df.rename(columns={"Field Goals_2": "FG%"})
df["FG%"] = df["FG%"].astype(float)
df[["Player", "FGM", "FGA", "FG%"]].head(20)
# Out:
#                 Player  FGM  FGA   FG%
# 0   Khalid Abdel-Gabar   91  205  44.4
# 1   Khalid Abdel-Gabar  146  368  39.7
# 2   Khalid Abdel-Gabar  237  573  41.4
# 3          Jamil Abiad   32   86  37.2
# 4          Jamil Abiad   11   33  33.3
# 5          Jamil Abiad   28   73  38.4
# 6          Jamil Abiad   71  192  37.0
# 7   Michael Acheampong  109  249  43.8
# 8   Michael Acheampong  117  316  37.0
# 9   Michael Acheampong  226  565  40.0
# 10     Daniel Adediran   14   29  48.3
# 11     Daniel Adediran   74  143  51.7
# 12     Daniel Adediran   50   78  64.1
# 13     Daniel Adediran   69  137  50.4
# 14     Daniel Adediran    0    0   0.0
# 15     Daniel Adediran  207  387  53.5
# 16         Bruce Adjei    9   15  60.0
# 17          Seth Adler   81  213  38.0
# 18          Seth Adler   81  200  40.5
# 19          Seth Adler   98  223  43.9

# %%
# Split Field Throw column
split_cols = df["Free Throws_1"].str.split("-", n=1, expand=True)
index = df.columns.get_loc("Free Throws_1")
df.insert(index + 1, "FTM", pd.to_numeric(split_cols[0], errors="coerce").astype("Int64"))
df.insert(index + 2, "FTA", pd.to_numeric(split_cols[1], errors="coerce").astype("Int64"))
df = df.drop(columns=["Free Throws_1"])

# Rename FT% Column
df = df.rename(columns={"Free Throws_2": "FT%"})
df["FT%"] = df["FT%"].astype(float)
df[["Player", "FTM", "FTA", "FT%"]].head(20)
# Out:
#                 Player  FTM  FTA   FT%
# 0   Khalid Abdel-Gabar   20   32  62.5
# 1   Khalid Abdel-Gabar   43   67  64.2
# 2   Khalid Abdel-Gabar   63   99  63.6
# 3          Jamil Abiad    6   10  60.0
# 4          Jamil Abiad    3    5  60.0
# 5          Jamil Abiad    1    2  50.0
# 6          Jamil Abiad   10   17  58.8
# 7   Michael Acheampong   42   63  66.7
# 8   Michael Acheampong   86  109  78.9
# 9   Michael Acheampong  128  172  74.4
# 10     Daniel Adediran    4    7  57.1
# 11     Daniel Adediran   33   47  70.2
# 12     Daniel Adediran   22   33  66.7
# 13     Daniel Adediran   27   45  60.0
# 14     Daniel Adediran    0    0   0.0
# 15     Daniel Adediran   86  132  65.2
# 16         Bruce Adjei    7   15  46.7
# 17          Seth Adler   73   96  76.0
# 18          Seth Adler   55   75  73.3
# 19          Seth Adler   62   83  74.7

# %%
# Rename Columns
df = df.rename(columns={"Rebounds_2": "REB", "Points_2": "PPG", "AS": "AST", "TO": "TOV", "BL": "BLK", "ST": "STL"})
df
# Out:
#                   Player Position Height         Hometown U Sports Team  \
# 0     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 1     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 2     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 3            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# 4            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# ...                  ...      ...    ...              ...           ...
# 3721      Henry Van Herk        F    6-9      Toronto, ON       Queen's
# 3722    Bas van Willigen        F    6-7      Netherlands          UCCB
# 3723   Samuel Willis III        G    6-1  Minneapolis, MN   Mount Royal
# 3724         Gilles Ysos        G    6-1     Agen, France          UQAM
# 3725    Luka Zaharijevic        F    6-8    Vancouver, BC           UBC
#
#        Season    GP    GS   MPG   3PM  ...   FTM   FTA   FT%  REB    PF  \
# 0     2013-14    27    11  22.5    27  ...    20    32  62.5  4.0  49.0
# 1     2014-15    30    30  30.2    53  ...    43    67  64.2  3.8  47.0
# 2       Total    57    41  26.5    80  ...    63    99  63.6  3.9  96.0
# 3     2009-10    23     0  11.0    21  ...     6    10  60.0  1.4  32.0
# 4     2012-13    12     0  11.6     4  ...     3     5  60.0  1.2  16.0
# ...       ...   ...   ...   ...   ...  ...   ...   ...   ...  ...   ...
# 3721      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN   NaN
# 3722      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN   NaN
# 3723      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN   NaN
# 3724      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN   NaN
# 3725      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN   NaN
#
#         AST   TOV  BLK   STL   PPG
# 0      54.0  36.0  6.0  50.0   8.5
# 1     100.0  60.0  3.0  41.0  12.9
# 2     154.0  96.0  9.0  91.0  10.8
# 3      14.0  31.0  NaN  13.0   4.0
# 4       7.0   4.0  NaN   5.0   2.4
# ...     ...   ...  ...   ...   ...
# 3721    NaN   NaN  NaN   NaN   NaN
# 3722    NaN   NaN  NaN   NaN   NaN
# 3723    NaN   NaN  NaN   NaN   NaN
# 3724    NaN   NaN  NaN   NaN   NaN
# 3725    NaN   NaN  NaN   NaN   NaN
#
# [3726 rows x 25 columns]

# %%
# Calculating per game stats
df["PF"] = (df["PF"] / df["GP"]).round(1)
df["AST"] = (df["AST"] / df["GP"]).round(1)
df["TOV"] = (df["TOV"] / df["GP"]).round(1)
df["BLK"] = (df["BLK"] / df["GP"]).round(1)
df["STL"] = (df["STL"] / df["GP"]).round(1)
df
# Out:
#                   Player Position Height         Hometown U Sports Team  \
# 0     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 1     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 2     Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor
# 3            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# 4            Jamil Abiad        G   5-11       Ottawa, ON      Bishop's
# ...                  ...      ...    ...              ...           ...
# 3721      Henry Van Herk        F    6-9      Toronto, ON       Queen's
# 3722    Bas van Willigen        F    6-7      Netherlands          UCCB
# 3723   Samuel Willis III        G    6-1  Minneapolis, MN   Mount Royal
# 3724         Gilles Ysos        G    6-1     Agen, France          UQAM
# 3725    Luka Zaharijevic        F    6-8    Vancouver, BC           UBC
#
#        Season    GP    GS   MPG   3PM  ...   FTM   FTA   FT%  REB    PF   AST  \
# 0     2013-14    27    11  22.5    27  ...    20    32  62.5  4.0   1.8   2.0
# 1     2014-15    30    30  30.2    53  ...    43    67  64.2  3.8   1.6   3.3
# 2       Total    57    41  26.5    80  ...    63    99  63.6  3.9   1.7   2.7
# 3     2009-10    23     0  11.0    21  ...     6    10  60.0  1.4   1.4   0.6
# 4     2012-13    12     0  11.6     4  ...     3     5  60.0  1.2   1.3   0.6
# ...       ...   ...   ...   ...   ...  ...   ...   ...   ...  ...   ...   ...
# 3721      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN  <NA>  <NA>
# 3722      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN  <NA>  <NA>
# 3723      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN  <NA>  <NA>
# 3724      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN  <NA>  <NA>
# 3725      NaN  <NA>  <NA>   NaN  <NA>  ...  <NA>  <NA>   NaN  NaN  <NA>  <NA>
#
#        TOV   BLK   STL   PPG
# 0      1.3   0.2   1.9   8.5
# 1      2.0   0.1   1.4  12.9
# 2      1.7   0.2   1.6  10.8
# 3      1.3  <NA>   0.6   4.0
# 4      0.3  <NA>   0.4   2.4
# ...    ...   ...   ...   ...
# 3721  <NA>  <NA>  <NA>   NaN
# 3722  <NA>  <NA>  <NA>   NaN
# 3723  <NA>  <NA>  <NA>   NaN
# 3724  <NA>  <NA>  <NA>   NaN
# 3725  <NA>  <NA>  <NA>   NaN
#
# [3726 rows x 25 columns]

# %%
df.to_excel("data/cleaned_usports_player_box_score_stats.xlsx", index=False, engine="openpyxl")

# %%
# Load career data for merging with cleaned stats
career_df = pd.read_excel("data/usports_career_data.xlsx")
career_df.head()
# Out:
#                Player   Season          Team
# 0  Khalid Abdel-Gabar  2013-14   MBB-Windsor
# 1  Khalid Abdel-Gabar  2014-15   MBB-Windsor
# 2         Jamil Abiad  2009-10  MBB-Bishop's
# 3         Jamil Abiad  2012-13  MBB-Bishop's
# 4         Jamil Abiad  2014-15  MBB-Bishop's

# %%
def merge_career_with_stats(career_df, stats_df):
    """Merge career data with USports stats based on season and player."""
    if career_df.empty or stats_df.empty:
        print("Cannot merge: one or both dataframes are empty")
        return pd.DataFrame()
    
    # Merge on Player and Season columns
    try:
        # Ensure Season column exists in stats_df
        if "Season" not in stats_df.columns:
            print("Warning: Season column not found in stats data. Cannot merge.")
            return stats_df
        
        career_df["Team"] = career_df["Team"].str.replace("MBB-", "", regex=True)
            
        merged_df = pd.merge(stats_df, career_df[["Player", "Season", "Team"]], 
                            on=["Player", "Season"], 
                            how="left")
        print(f"Successfully merged career and stats data. Result has {len(merged_df)} rows.")
        return merged_df
        
    except Exception as e:
        print(f"Error merging career and stats data: {e}")
        return stats_df

# Merge career data with cleaned stats
print("Merging career data with cleaned stats...")
merged_df = merge_career_with_stats(career_df, df)
merged_df.head()
# Out:
# Merging career data with cleaned stats...
# Successfully merged career and stats data. Result has 3726 rows.
#                Player Position Height         Hometown U Sports Team   Season  \
# 0  Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor  2013-14
# 1  Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor  2014-15
# 2  Khalid Abdel-Gabar        G    6-2  Mississauga, ON       Windsor    Total
# 3         Jamil Abiad        G   5-11       Ottawa, ON      Bishop's  2009-10
# 4         Jamil Abiad        G   5-11       Ottawa, ON      Bishop's  2012-13
#
#    GP  GS   MPG  3PM  ...  FTA   FT%  REB   PF  AST  TOV   BLK  STL   PPG  \
# 0  27  11  22.5   27  ...   32  62.5  4.0  1.8  2.0  1.3   0.2  1.9   8.5
# 1  30  30  30.2   53  ...   67  64.2  3.8  1.6  3.3  2.0   0.1  1.4  12.9
# 2  57  41  26.5   80  ...   99  63.6  3.9  1.7  2.7  1.7   0.2  1.6  10.8
# 3  23   0  11.0   21  ...   10  60.0  1.4  1.4  0.6  1.3  <NA>  0.6   4.0
# 4  12   0  11.6    4  ...    5  60.0  1.2  1.3  0.6  0.3  <NA>  0.4   2.4
#
#        Team
# 0   Windsor
# 1   Windsor
# 2       NaN
# 3  Bishop's
# 4  Bishop's
#
# [5 rows x 26 columns]

# %%
def validate_player_counts(usports_stats_with_teams_df, pro_season_data_df):
    """Validate that the number of unique players in both datasets is equal."""
    if usports_stats_with_teams_df.empty or pro_season_data_df.empty:
        print("Warning: Cannot validate player counts - one or both datasets are empty")
        return False
    
    # Get unique player counts from both datasets
    usports_unique_players = usports_stats_with_teams_df['Player'].nunique()
    pro_unique_players = pro_season_data_df['Player'].nunique()
    
    print(f"Unique players in usports_stats_with_teams: {usports_unique_players}")
    print(f"Unique players in pro_season_data: {pro_unique_players}")
    
    if usports_unique_players == pro_unique_players:
        print("✓ VALIDATION PASSED: Player counts match!")
        return True
    else:
        print("✗ VALIDATION FAILED: Player counts do not match!")
        
        # Show which players are missing from each dataset
        usports_players = set(usports_stats_with_teams_df['Player'].unique())
        pro_players = set(pro_season_data_df['Player'].unique())
        
        missing_from_usports = pro_players - usports_players
        missing_from_pro = usports_players - pro_players
        
        if missing_from_usports:
            print(f"Players in pro_season_data but not in usports_stats_with_teams: {missing_from_usports}")
        if missing_from_pro:
            print(f"Players in usports_stats_with_teams but not in pro_season_data: {missing_from_pro}")
        
        return False

# Load pro season data for validation
try:
    pro_seasons_df = pd.read_excel("data/pro_season_data.xlsx")
    print("Validating player counts...")
    validate_player_counts(merged_df, pro_seasons_df)
except FileNotFoundError:
    print("Pro season data file not found. Skipping validation.")
except Exception as e:
    print(f"Error loading pro season data: {e}")
# Out:
# Validating player counts...
# Unique players in usports_stats_with_teams: 954
# Unique players in pro_season_data: 954
# ✓ VALIDATION PASSED: Player counts match!

# %%
# Rename columns as requested
merged_df = merged_df.rename(columns={
    "U Sports Team": "All USports Teams Played For",
    "Team": "USports Team"
})

# Reorder columns to move USports Team to the right of Hometown
cols = list(merged_df.columns)
hometown_idx = cols.index("Hometown")
usports_team_idx = cols.index("USports Team")

# Remove USports Team from its current position
cols.remove("USports Team")
# Insert it right after Hometown
cols.insert(hometown_idx + 1, "USports Team")

# Reorder the dataframe
merged_df = merged_df[cols]

# Save the final merged dataset
if not merged_df.empty:
    merged_df.to_excel("data/usports_stats_with_teams.xlsx", index=False, engine="openpyxl")
    print("Final merged dataset saved to data/usports_stats_with_teams.xlsx")
    print(f"Dataset contains {len(merged_df)} rows and {len(merged_df.columns)} columns")
    print(f"Unique players: {merged_df['Player'].nunique()}")
    print(f"Column order: {list(merged_df.columns[:8])}")  # Show first 8 columns to verify order
else:
    print("Merged dataframe is empty - not saving")
# Out:
# Final merged dataset saved to data/usports_stats_with_teams.xlsx
# Dataset contains 3726 rows and 26 columns
# Unique players: 954
# Column order: ['Player', 'Position', 'Height', 'Hometown', 'USports Team', 'All USports Teams Played For', 'Season', 'GP']
